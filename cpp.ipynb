# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import numba as nb
from scipy.optimize import minimize
from mpl_toolkits import mplot3d

import matplotlib.pyplot as plt
from consav.grids import nonlinspace

from BufferStockModel import BufferStockModelClass

# %%
model2 = BufferStockModelClass()

# %%
model = BufferStockModelClass()
model.link_to_cpp(do_print=False)
# Out:
# cppfuncs/par_struct.cpp
# cppfuncs/sol_struct.cpp
# cppfuncs/sim_struct.cpp
# ['cd /d "C:/Program Files/Microsoft Visual Studio/2022/Community/VC/Auxiliary/Build/"\n', 'call vcvarsall.bat x64\n', 'cd /d "c:\\Users\\Simon\\Desktop\\EconModelDebugging"\n', 'cl /LD /EHsc /O2 /openmp cppfuncs/solve.cpp setup_omp.cpp cppfuncs/nlopt-2.4.2-dll64/libnlopt-0.lib  \n']

# %%
model.cpp.solve(model.sol,model.par)

# %%
model.sol.c.size
# Out:
# 4000
