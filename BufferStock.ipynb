# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import numba as nb
from scipy.optimize import minimize
from mpl_toolkits import mplot3d

import matplotlib.pyplot as plt
from consav.grids import nonlinspace
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# load local model file and initialize model class
from BufferStockModel import BufferStockModelClass
model = BufferStockModelClass()

from BufferStockModel2 import BufferStockModelClass as BufferStockModelClass2
model2 = BufferStockModelClass2()

# %%
model.solve()
par = model.par
sol = model.sol

# %%
model_egm = BufferStockModelClass()
model_egm.solve_egm()

model2_egm = BufferStockModelClass2(par={"method":"egm"})
model2_egm.solve()

# %%
model2.solve()

# %%
plt.plot(model_egm.sol.c[0] )
plt.plot(model.sol.c[0] , linestyle = "--")
plt.plot(model2.sol.c[0] , linestyle = ":")
plt.plot(model2_egm.sol.c[0] , linestyle = ":")

# %%
ia = 145
print(model_egm.sol.c[-2,ia] , model.sol.c[-2,ia])
# Out:
# 20.830272227839256 20.82268195854757

# %%
plt.plot(model_egm.sol.c[0] - model.sol.c[0])
#plt.plot(model.sol.V[0], linestyle="--")

# %%
plt.plot(model_egm.sol.V[0,150:]-model.sol.V[0,150:])

# %%
plt.plot(model_egm.sol.V[0,150:])
plt.plot( model.sol.V[0,150:],linestyle = "--")

# %%
plt.plot(model_egm.sol.c[0])
plt.plot( model.sol.c[0],linestyle = "--")
